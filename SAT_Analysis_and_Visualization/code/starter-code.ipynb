# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:**
#
# This project aims to study SAT scores and compare them to their counterparts.  More specifically we will be looking at the major west coast states (CA, OR, WA) and compare their SAT scores and statistics to a few east coast states that are not mandated to take the SATs.  We hope to find strengths/weaknesses of the states test takers and decide which one needs help allocating resourches to improve test scores.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*
# #outside research (what data not included in the project that you can use for your project
# #i.e low income students vs high income students!!
#
# note:  look up the data not necessarily processing it now

# %% [markdown]
# We will be looking major states of the west and east coast and comparing them against each other.  We want to see what are the characteristics of the state, i.e population makeup, to analyze the factors that leads to the state to its overall score.  We want to investigate if their is a major difference that is going between the west and east coast.  We will be looking at individual state SAT statistics to get a deeper understanding. The east and west coast of the country holds the majoirty of the population, so looking at these states gives a very good sample size of what is possibly happening in sections of the country.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# sat_2017.csv
#
# sat_2018.csv
#
# sat_2019.csv

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*
#
# 2018 SAT Statistics from Collegeboard
# https://reports.collegeboard.org/pdf/2018-total-group-sat-suite-assessments-annual-report.pdf
#
# ACT data 2018
# https://www.act.org/content/dam/act/unsecured/documents/cccr2018/National-CCCR-2018.pdf
# ^page 9 for our low income vs high income students
#
# ACT data from 2010
# https://www.act.org/content/dam/act/unsecured/documents/Catching-Up-To-College-and-Career-Readiness.pdf
#
# ACT income data 2012 - 2016
# https://www.act.org/content/dam/act/unsecured/documents/R1604-ACT-Composite-Score-by-Family-Income.pdf
#
#
# California data: SAT
# https://reports.collegeboard.org/pdf/2018-california-sat-suite-assessments-annual-report.pdf
#
# CA ACT 2019: from 2015 to 2019
# https://www.act.org/content/dam/act/unsecured/documents/cccr-2019/California-CCCR-2019.pdf
#
#
# census household income data:
# https://www.census.gov/library/publications/2019/demo/p60-266.html

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
#just create the the ftn creating giving back the mean WITHOUT USING ANY LIBRARIES

def mean(some_numbers):
    number_add = 0
    for num in some_numbers:
        number_add = number_add + num
    return number_add/(len(some_numbers))  #divide the total by the amount of numbers in the list .. so use len()




X = [1.1234,2,3,4,5] #mean of this is 3
    
mean(X)
# Out:
# 3.02468

# %%
#len(X)   #returns 5

# for num in range(len(X)):
#     print(num + 1)  #we need to add +1 bec real world index dont start at 1

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.
#
#
#
#
#
#     #ex given an input list could you calc the std dev of that list!!

# %%
# Code:
def std_dev(sample):
    u = mean(sample)  #our mean
    summation = 0  #need to add up all the (xi - u)^2 into a variable
                #then divide it by N which reprresents the number of variables
        #x_i represents the variable...... (varaible - mean) ^2
        
    for num in sample:
        doing_math = (num - u)**2 
        summation = summation + doing_math
        
    return float((summation/len(sample))**(1/2))

# %%
std_dev(X)  #sweet checks out
# Out:
# 1.379752300088679

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code: basically convert your string of 50% to a float.. .5
def conv_to_dec(num):
    try:
        num = num.replace('%','')
        return (float(num)/100)
    except AttributeError:
        print('Already Converted!!!')
    
    
##okay im going to try the 'try' and 'except' thing so that i can call it more hten once without the error but 
#print out a message if it is an error

# %%
str_n = '30.5%'

# %%
# x = str_n.replace('%', '')
# x
x = conv_to_dec(str_n)  #checks out!
x
# Out:
# 0.305

# %%
conv_to_dec(x)
# Out:
# Already Converted!!!

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')  # # the 2 dots  (..) means goes back a folder.. similar to git: cd ..
sat_2018.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#reminder printing without index:
#sat_2018.style.hide_index()

# %%
#msno.bar(sat_2018, log=True)  #no missing values for this one either

# %%
act_2018.info()  #change particpiation columns using the conv_to_percent ftn i made
#i have a duplicate row 'Maine' get rid of that
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
#act_2018 = act_2018.drop_duplicates()

# %%
#act_2018.info()

# %%
#act_2018.to_csv('../data/act_sample_2018.csv')  #alright duplicate Maine row is gone!!!!

# %%
#not doing ACT data anymore .. just SAT data!!
#try using .apply on the Participation column for act
# dummie_f = act_2018
# #dummie_f.head()

# try:
#     dummie_f['Participation'] = dummie_f['Participation'].map(conv_to_dec)  #call this once or it will throw an error- do the try except method
# except:
#     print('Already converted to decimals!')

#^^ .apply vs .map vs .applymap:
#apply works on a row / column basis of a DataFrame, applymap works element-wise on a DataFrame, and map works element-wise on a Series
# hmm not seeing difference b/w .apply vs .applymap------------

# %%
#dummie_f.head()

# %%
#dummie_f.info()

# %%
# dummie_f.columns

# %%
#dummie_f.rename(columns={'State':'state','Participation':'participation_for_act','Composite':'act_composite_score' }, inplace=True); #renamed the columns for act
                                                                                                            #remember to set inplace to True so it saves it!

# %%
# act_2018 = dummie_f
# act_2018.head()

# %%
# act_2018.shape

# %%
#========= now for SAT file=============
sat_2018.info()  #change participation from string percentage to float  i.e 50% to .50
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#try:
#sat_2018['Participation'] = sat_2018['Participation'].apply(conv_to_dec)  #call this once or it will throw an error- do the try except method
####CALL THIS ONCE OR IT WILL DO WEIRD STUFF ^^^ ask in office hours !!!
# except:
#     print('Already converted to decimals!')  #okay weird.. why is it this one prints out the except x50 but not the one above?!??!

# %%
sat_2018.head()  #participation column converted!
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat_2018.shape
# Out:
# (51, 5)

# %%
#----rename SAT columns    2018----
sat_2018.rename(columns={'State':'state','Participation':'participation_2018',
                         'Evidence-Based Reading and Writing':'reading_writing_score_2018',
                        'Math':'math_score_2018', 'Total':'sat_total_2018'}, inplace=True); #renamed the columns for sat
                                                                                                            #remember to set inplace to True so it saves it!
    #----rename SAT columns    2017----
sat_2017.rename(columns={'State':'state','Participation':'participation_2017',
                         'Evidence-Based Reading and Writing':'reading_writing_score_2017',
                        'Math':'math_score_2017', 'Total':'sat_total_2017'}, inplace=True);

# %%
sat_2018.head()
# Out:
#         state participation_2018  reading_writing_score_2018  math_score_2018  \
# 0     Alabama                 6%                         595              571
# 1      Alaska                43%                         562              544
# 2     Arizona                29%                         577              572
# 3    Arkansas                 5%                         592              576
# 4  California                60%                         540              536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
sat_2017.head()
# Out:
#         state participation_2017  reading_writing_score_2017  math_score_2017  \
# 0     Alabama                 5%                         593              572
# 1      Alaska                38%                         547              533
# 2     Arizona                30%                         563              553
# 3    Arkansas                 3%                         614              594
# 4  California                53%                         531              524
#
#    sat_total_2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %%
#to change strings in a DATAFRAME you must use the following syntax:   .str.(w/e transformation)
#.str lets you access the string in a series
#also it excludes missing/NA  i.e np.nan
#sat_2018['state'] = sat_2018['state'].str.lower()

# %%
# sat_2018.head(10)

# %%
# act_2018['state'] = act_2018['state'].str.lower()
# act_2018.head(10)

# %%
#lets merge baby!!!!
#so i want to merge act_2018 to the right side of my sat_2018 dataframe

# %%
sat_2017_18_stats = pd.merge(sat_2017,sat_2018, how='left')

# %%
sat_2017_18_stats.head(10) #sweet got the output i wanted which was act stats on the left side
# Out:
#                   state participation_2017  reading_writing_score_2017  \
# 0               Alabama                 5%                         593
# 1                Alaska                38%                         547
# 2               Arizona                30%                         563
# 3              Arkansas                 3%                         614
# 4            California                53%                         531
# 5              Colorado                11%                         606
# 6           Connecticut               100%                         530
# 7              Delaware               100%                         503
# 8  District of Columbia               100%                         482
# 9               Florida                83%                         520
#
#    math_score_2017  sat_total_2017 participation_2018  \
# 0              572            1165                 6%
# 1              533            1080                43%
# ...

# %%
 # need to clean up sat_2019 data  abit bec of virgin islands and puerto rico.. need to take it out

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2019.tail(14)
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 40    Rhode Island               100%   503   492    995
# 41  South Carolina                68%   526   504   1030
# 42    South Dakota                 3%   633   635   1268
# 43       Tennessee                 7%   618   602   1220
# 44           Texas                68%   515   507   1022
# 45            Utah                 4%   614   615   1230
# 46         Vermont                66%   560   546   1106
# 47  Virgin Islands                  —   490   445    935
# 48        Virginia                68%   567   551   1119
# 49      Washington                70%   539   535   1074
# 50   West Virginia                99%   483   460    943
# 51       Wisconsin                 3%   635   648   1283
# 52         Wyoming                 3%   623   615   1238

# %%
#sat_2019.drop(index=52) #oh look specifying index will remove that row
#virgin islands is index 47  ... puerto rico is 39
#sat_2019.drop(index=[0,1]) #oh you can also remove by setting index to a list of w/e index you want

#this does do it
try:
    sat_2019.drop(index=[39,47], inplace=True)
except:
    pass

# %%
sat_2019.head(6)
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065
# 5    Colorado               100%   518   506   1024

# %%
# RENAME 2019 file columns
sat_2019.rename(columns={'State':'state','Participation Rate':'participation_2019',
                         'EBRW':'reading_writing_score_2019',
                        'Math':'math_score_2019', 'Total':'sat_total_2019'}, inplace=True);

# %%
sat_2019.head()
# Out:
#         state participation_2019  reading_writing_score_2019  math_score_2019  \
# 0     Alabama                 7%                         583              560
# 1      Alaska                41%                         556              541
# 2     Arizona                31%                         569              565
# 3    Arkansas                 6%                         582              559
# 4  California                63%                         534              531
#
#    sat_total_2019
# 0            1143
# 1            1097
# 2            1134
# 3            1141
# 4            1065

# %%
sat_2017_18_19_stats = pd.merge(sat_2017_18_stats,sat_2019, how='left')

# %%
sat_2017_18_19_stats.head()
# Out:
#         state participation_2017  reading_writing_score_2017  math_score_2017  \
# 0     Alabama                 5%                         593              572
# 1      Alaska                38%                         547              533
# 2     Arizona                30%                         563              553
# 3    Arkansas                 3%                         614              594
# 4  California                53%                         531              524
#
#    sat_total_2017 participation_2018  reading_writing_score_2018  \
# 0            1165                 6%                         595
# 1            1080                43%                         562
# 2            1116                29%                         577
# 3            1208                 5%                         592
# 4            1055                60%                         540
#
#    math_score_2018  sat_total_2018 participation_2019  \
# ...

# %%
#lets convert the percentage!
dummie_f = sat_2017_18_19_stats
dummie_f.head()
# Out:
#         state participation_2017  reading_writing_score_2017  math_score_2017  \
# 0     Alabama                 5%                         593              572
# 1      Alaska                38%                         547              533
# 2     Arizona                30%                         563              553
# 3    Arkansas                 3%                         614              594
# 4  California                53%                         531              524
#
#    sat_total_2017 participation_2018  reading_writing_score_2018  \
# 0            1165                 6%                         595
# 1            1080                43%                         562
# 2            1116                29%                         577
# 3            1208                 5%                         592
# 4            1055                60%                         540
#
#    math_score_2018  sat_total_2018 participation_2019  \
# ...

# %%
dummie_f[['participation_2017','participation_2018','participation_2019']] = dummie_f[['participation_2017','participation_2018','participation_2019']].applymap(conv_to_dec)  #call this once or it will throw an error- do the try except method
# since im doing dataframe syntax here .apply will not work unless its a series... not even .apply
#has to be .applymap

# %%
dummie_f.head()
# Out:
#         state  participation_2017  reading_writing_score_2017  \
# 0     Alabama                0.05                         593
# 1      Alaska                0.38                         547
# 2     Arizona                0.30                         563
# 3    Arkansas                0.03                         614
# 4  California                0.53                         531
#
#    math_score_2017  sat_total_2017  participation_2018  \
# 0              572            1165                0.06
# 1              533            1080                0.43
# 2              553            1116                0.29
# 3              594            1208                0.05
# 4              524            1055                0.60
#
#    reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 0                         595              571            1166
# 1                         562              544            1106
# 2                         577              572            1149
# ...

# %%
# #now save the stats into a file
# sat_act_2018_stats.to_csv('../data/act_sat_2018.csv')  #oh no District of columbia data didnt merge right because of capitalization. time to lowercase state column
#                                                         #fixed

# %%
# [word.title() for word in sat_act_2018_stats['state']]    #incase i want to capitalize the states properly

# %%
dummie_f.to_csv('../data/sat_2017_18_19.csv')

# %%
sat_stats = pd.read_csv('../data/sat_2017_18_19.csv')

# %%
sat_stats.head(); # drop unnamed: 0

# %%
sat_stats.drop(['Unnamed: 0'], axis=1, inplace=True);

# %%
sat_stats.head()
# Out:
#         state  participation_2017  reading_writing_score_2017  \
# 0     Alabama                0.05                         593
# 1      Alaska                0.38                         547
# 2     Arizona                0.30                         563
# 3    Arkansas                0.03                         614
# 4  California                0.53                         531
#
#    math_score_2017  sat_total_2017  participation_2018  \
# 0              572            1165                0.06
# 1              533            1080                0.43
# 2              553            1116                0.29
# 3              594            1208                0.05
# 4              524            1055                0.60
#
#    reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 0                         595              571            1166
# 1                         562              544            1106
# 2                         577              572            1149
# ...

# %%
sat_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   state                       51 non-null     object
#  1   participation_2017          51 non-null     float64
#  2   reading_writing_score_2017  51 non-null     int64
#  3   math_score_2017             51 non-null     int64
#  4   sat_total_2017              51 non-null     int64
#  5   participation_2018          51 non-null     float64
#  6   reading_writing_score_2018  51 non-null     int64
#  7   math_score_2018             51 non-null     int64
#  8   sat_total_2018              51 non-null     int64
#  9   participation_2019          51 non-null     float64
#  10  reading_writing_score_2019  51 non-null     int64
#  11  math_score_2019             51 non-null     int64
#  12  sat_total_2019              51 non-null     int64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|Name of states|50 states of USA and District of Columbia|
# |participation_2017|float|SAT 2017 Data|The partipcation rate of students that took the SAT in 2017 in that state (unit is in decimal, where .50 represents %50)|
# |reading_writing_score_2017|int|SAT 2017 Data|Mean score of the reading & writing score of students that took the SAT in 2017|
# |math_score_2017|int|SAT 2017 Data|Mean score of the math score of students that took the SAT in 2017 |
# |sat_total_2017|int|SAT 2017 Data|Mean score of the students combined score of math score & reading/writing score for the SAT in 2017|
# |participation_2018|float|SAT 2018 Data|The partipcation rate of students that took the SAT in 2018 in that state (unit is in decimal, where .50 represents %50)|
# |reading_writing_score_2018|int|SAT 2018 Data|Mean score of the reading & writing score of students that took the SAT in 2018|
# |math_score_2018|int|SAT 2018 Data|Mean score of the math score of students that took the SAT in 2018 |
# |sat_total_2018|int|SAT 2018 Data|Mean score of the students combined score of math score & reading/writing score for the SAT in 2018|
# |participation_2019|float|SAT 2019 Data|The partipcation rate of students that took the SAT in 2019 in that state (unit is in decimal, where .50 represents %50)|
# |reading_writing_score_2019|int|SAT 2019 Data|Mean score of the reading & writing score of students that took the SAT in 2019|
# |math_score_2019|int|SAT 2019 Data|Mean score of the math score of students that took the SAT in 2019 |
# |sat_total_2019|int|SAT 2019 Data|Mean score of the students combined score of math score & reading/writing score for the SAT in 2019|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:
sat_stats.head()
# Out:
#    Unnamed: 0       state  participation_2017  reading_writing_score_2017  \
# 0           0     Alabama                0.05                         593
# 1           1      Alaska                0.38                         547
# 2           2     Arizona                0.30                         563
# 3           3    Arkansas                0.03                         614
# 4           4  California                0.53                         531
#
#    math_score_2017  sat_total_2017  participation_2018  \
# 0              572            1165                0.06
# 1              533            1080                0.43
# 2              553            1116                0.29
# 3              594            1208                0.05
# 4              524            1055                0.60
#
#    reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 0                         595              571            1166
# ...

# %%
#state_list = ['Alabama', 'Alaska']

# %%
#sat_stats['state']

# %%
# for x in sat_stats['state']:
#     if x in state_list:
#         print(x)

# %%
# mask = sat_stats['state'].isin(state_list);  #ooh this way  .. ty isin ftn
# sat_stats[mask]

# %%
# mask = sat_stats.isin(state_list)
# sat_stats[mask]    #doing it this way will returna  table full of NaN and just show w/e was True which would only show alabama and alaska 
# but their values would come out as NaN

# %%
##===============CREATING MY DATAFRAME FOR MY WEST COAST VS EAST COAST =============================##
west_list = ['California', 'Oregon', 'Washington']
east_list = ['New York', 'Virginia','North Carolina']

# %%
mask_w = sat_stats['state'].isin(west_list);
mask_e = sat_stats['state'].isin(east_list);

# %%
west_sat = sat_stats[mask_w];
east_sat = sat_stats[mask_e];

# %%
west_sat.head()
# Out:
#     Unnamed: 0       state  participation_2017  reading_writing_score_2017  \
# 4            4  California                0.53                         531
# 37          37      Oregon                0.43                         560
# 47          47  Washington                0.64                         541
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 4               524            1055                0.60
# 37              548            1108                0.48
# 47              534            1075                0.69
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 4                          540              536            1076
# 37                         564              553            1117
# 47                         543              538            1081
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 4                 0.63                         534              531
# ...

# %%
east_sat.head()
# Out:
#              state  participation_2017  reading_writing_score_2017  \
# 32        New York                0.67                         528
# 33  North Carolina                0.49                         546
# 46        Virginia                0.65                         561
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 32              523            1052                0.79
# 33              535            1081                0.52
# 46              541            1102                0.68
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 32                         534              534            1068
# 33                         554              543            1098
# 46                         567              550            1117
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 32                0.79                         531              533
# 33                0.51                         554              546
# ...

# %%
#east_sat['participation_2017'].tolist()

# %%
# for x in east_sat.columns:
#     print(x)  #oooh how we return column names hehe

# %%
std_dev

# %%
east_west_sat = pd.concat([west_sat, east_sat])  #axis parameter automatically 0 which means on row
                #reminder, to concat dataframes together you need to pass as list in the argument for concat!

# %%
east_west_sat
# Out:
#              state  participation_2017  reading_writing_score_2017  \
# 4       California                0.53                         531
# 37          Oregon                0.43                         560
# 47      Washington                0.64                         541
# 32        New York                0.67                         528
# 33  North Carolina                0.49                         546
# 46        Virginia                0.65                         561
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 4               524            1055                0.60
# 37              548            1108                0.48
# 47              534            1075                0.69
# 32              523            1052                0.79
# 33              535            1081                0.52
# 46              541            1102                0.68
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# ...

# %%
#=========================================================================================================
##=========================================================================================================

# %%
#What are the top participating states to take the SAT for 3 years in a row? ###################################

# %%
# test1 = {colname : value for colName,value in east_sat} # nope this doesnt work

# %%
#sd = {column: sat_stats[column].apply(std_dev) for column in sat_stats.columns if column != 'state'}
# ^ this gives a TypeError: 'float' object is not iterable bec we are passing in just a number into our ftn that is expecting an input of a LIST of numbers
#    need to make the column values into a list

sd = {column: std_dev(sat_stats[column].tolist()) for column in sat_stats.columns if column != 'state'} #this is the way!
sd
# Out:
# {'participation_2017': 0.3492907076664507,
#  'reading_writing_score_2017': 45.21697020437866,
#  'math_score_2017': 84.07255521608297,
#  'sat_total_2017': 91.58351056778743,
#  'participation_2018': 0.3694661922353942,
#  'reading_writing_score_2018': 47.03460978357609,
#  'math_score_2018': 47.30194550378352,
#  'sat_total_2018': 93.22742384464433,
#  'participation_2019': 0.3836584048685726,
#  'reading_writing_score_2019': 45.792378682545134,
#  'math_score_2019': 50.78521461840036,
#  'sat_total_2019': 96.24027185617864}

# %%
sat_stats.sort_values(by='participation_2017', ascending=False).head(10)
# Out:
#                    state  participation_2017  reading_writing_score_2017  \
# 8   District of Columbia                1.00                         482
# 22              Michigan                1.00                         509
# 6            Connecticut                1.00                         530
# 7               Delaware                1.00                         503
# 29         New Hampshire                0.96                         532
# 19                 Maine                0.95                         513
# 12                 Idaho                0.93                         513
# 9                Florida                0.83                         520
# 21         Massachusetts                0.76                         555
# 39          Rhode Island                0.71                         539
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 8               468             950                0.92
# ...

# %%
sat_stats.sort_values(by='participation_2017', ascending=False).tail(10)
# Out:
#            state  participation_2017  reading_writing_score_2017  \
# 49     Wisconsin                0.03                         642
# 25      Missouri                0.03                         640
# 41  South Dakota                0.03                         612
# 27      Nebraska                0.03                         629
# 23     Minnesota                0.03                         644
# 3       Arkansas                0.03                         614
# 50       Wyoming                0.03                         626
# 34  North Dakota                0.02                         635
# 24   Mississippi                0.02                         634
# 15          Iowa                0.02                         641
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 49              649            1291                0.03
# 25              631            1271                0.04
# 41              603            1216                0.03
# ...

# %%
sat_stats.sort_values(by=['participation_2017', 'participation_2018'], ascending=False).head(10)
# Out:
#                    state  participation_2017  reading_writing_score_2017  \
# 6            Connecticut                1.00                         530
# 7               Delaware                1.00                         503
# 22              Michigan                1.00                         509
# 8   District of Columbia                1.00                         482
# 29         New Hampshire                0.96                         532
# 19                 Maine                0.95                         513
# 12                 Idaho                0.93                         513
# 9                Florida                0.83                         520
# 21         Massachusetts                0.76                         555
# 39          Rhode Island                0.71                         539
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 6               512            1041                1.00
# ...

# %%
sat_stats.sort_values(by=['participation_2017', 'participation_2018'], ascending=False).tail(10)
# Out:
#            state  participation_2017  reading_writing_score_2017  \
# 23     Minnesota                0.03                         644
# 25      Missouri                0.03                         640
# 44          Utah                0.03                         624
# 27      Nebraska                0.03                         629
# 41  South Dakota                0.03                         612
# 49     Wisconsin                0.03                         642
# 50       Wyoming                0.03                         626
# 15          Iowa                0.02                         641
# 24   Mississippi                0.02                         634
# 34  North Dakota                0.02                         635
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 23              651            1295                0.04
# 25              631            1271                0.04
# 44              614            1238                0.04
# ...

# %%
sat_stats.sort_values(by=['participation_2017', 'participation_2018', 'participation_2019'], ascending=False).head(10)
# Out:
#     Unnamed: 0                 state  participation_2017  \
# 6            6           Connecticut                1.00
# 7            7              Delaware                1.00
# 22          22              Michigan                1.00
# 8            8  District of Columbia                1.00
# 29          29         New Hampshire                0.96
# 19          19                 Maine                0.95
# 12          12                 Idaho                0.93
# 9            9               Florida                0.83
# 21          21         Massachusetts                0.76
# 39          39          Rhode Island                0.71
#
#     reading_writing_score_2017  math_score_2017  sat_total_2017  \
# 6                          530              512            1041
# 7                          503              492             996
# 22                         509              495            1005
# 8                          482              468             950
# ...

# %%
sat_stats.sort_values(by=['participation_2017', 'participation_2018', 'participation_2019'], ascending=False).tail(10)
# Out:
#     Unnamed: 0         state  participation_2017  reading_writing_score_2017  \
# 23          23     Minnesota                0.03                         644
# 25          25      Missouri                0.03                         640
# 44          44          Utah                0.03                         624
# 27          27      Nebraska                0.03                         629
# 41          41  South Dakota                0.03                         612
# 49          49     Wisconsin                0.03                         642
# 50          50       Wyoming                0.03                         626
# 15          15          Iowa                0.02                         641
# 24          24   Mississippi                0.02                         634
# 34          34  North Dakota                0.02                         635
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 23              651            1295                0.04
# ...

# %%
sat_stats.sort_values(by='sat_total_2017', ascending=True).head(10)
# Out:
#     Unnamed: 0                 state  participation_2017  \
# 8            8  District of Columbia                1.00
# 7            7              Delaware                1.00
# 12          12                 Idaho                0.93
# 22          22              Michigan                1.00
# 19          19                 Maine                0.95
# 9            9               Florida                0.83
# 43          43                 Texas                0.62
# 6            6           Connecticut                1.00
# 36          36              Oklahoma                0.07
# 10          10               Georgia                0.61
#
#     reading_writing_score_2017  math_score_2017  sat_total_2017  \
# 8                          482              468             950
# 7                          503              492             996
# 12                         513              493            1005
# 22                         509              495            1005
# ...

# %%
sat_stats.loc[sat_stats['state'] == 'Arkansas',:]
# Out:
#    Unnamed: 0     state  participation_2017  reading_writing_score_2017  \
# 3           3  Arkansas                0.03                         614
#
#    math_score_2017  sat_total_2017  participation_2018  \
# 3              594            1208                0.05
#
#    reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 3                         592              576            1169
#
#    participation_2019  reading_writing_score_2019  math_score_2019  \
# 3                0.06                         582              559
#
#    sat_total_2019
# 3            1141

# %%
west_sat.sort_values(by='participation_2017', ascending=False)
# Out:
#          state  participation_2017  reading_writing_score_2017  \
# 47  Washington                0.64                         541
# 4   California                0.53                         531
# 37      Oregon                0.43                         560
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 47              534            1075                0.69
# 4               524            1055                0.60
# 37              548            1108                0.48
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 47                         543              538            1081
# 4                          540              536            1076
# 37                         564              553            1117
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 47                0.70                         539              535
# 4                 0.63                         534              531
# ...

# %%
east_sat.sort_values(by='participation_2017', ascending=False)
# Out:
#              state  participation_2017  reading_writing_score_2017  \
# 32        New York                0.67                         528
# 46        Virginia                0.65                         561
# 33  North Carolina                0.49                         546
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 32              523            1052                0.79
# 46              541            1102                0.68
# 33              535            1081                0.52
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 32                         534              534            1068
# 46                         567              550            1117
# 33                         554              543            1098
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 32                0.79                         531              533
# 46                0.68                         567              551
# ...

# %%
west_sat['sat_total_2017'].mean()
# Out:
# 1079.3333333333333

# %%
east_sat['sat_total_2017'].mean()
# Out:
# 1078.3333333333333

# %%
west_sat.sort_values(by=[ 'math_score_2017', 'math_score_2018', 'math_score_2019'], ascending=False)
# Out:
#          state  participation_2017  reading_writing_score_2017  \
# 37      Oregon                0.43                         560
# 47  Washington                0.64                         541
# 4   California                0.53                         531
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 37              548            1108                0.48
# 47              534            1075                0.69
# 4               524            1055                0.60
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 37                         564              553            1117
# 47                         543              538            1081
# 4                          540              536            1076
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 37                0.51                         562              550
# 47                0.70                         539              535
# ...

# %%
east_sat.sort_values(by=['math_score_2017', 'math_score_2018', 'math_score_2019'], ascending=False)
# Out:
#              state  participation_2017  reading_writing_score_2017  \
# 46        Virginia                0.65                         561
# 33  North Carolina                0.49                         546
# 32        New York                0.67                         528
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 46              541            1102                0.68
# 33              535            1081                0.52
# 32              523            1052                0.79
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 46                         567              550            1117
# 33                         554              543            1098
# 32                         534              534            1068
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 46                0.68                         567              551
# 33                0.51                         554              546
# ...

# %% [markdown]
# **Trend analysis** *Edit this cell with your findings on trends in the data (step 3 above).*
# Looking at SAT data from the years 2017-2019, there is a noticeable trend that the top 5 participating in SATs are Connecticut, Delaware, Michigan, District of Columbia, and New Hampshire.  Digging deeper into this trend, there are state mandates for these states for student to require taking the SAT.
# Also looking at the lowest participating states, we see North Dakota, Mississippi, Iowa, Wyoming, and Wisconsin repeatedly. We see from these low participating states that they also have the highest SAT average score but that is most likely due to the low amount of people that are taking the test. And also, looking at the lowest SAT average score, the states with highest participation rate are up their, for example District of Columbia, Delaware, Michigan, and Maine.
#
# Now looking at the big west coast states versus a few east coast states. East coast states were chosen based on participation rates that almost matches the rates of the west coast states of CA, OR, and WA. East coast states that were chosen are NY, VA, and NC. Averaging out the east and west coasts total SAT score, they have a 1 point difference in the Sat_total_2017 score.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code
sat_stats.head()
# Out:
#    Unnamed: 0       state  participation_2017  reading_writing_score_2017  \
# 0           0     Alabama                0.05                         593
# 1           1      Alaska                0.38                         547
# 2           2     Arizona                0.30                         563
# 3           3    Arkansas                0.03                         614
# 4           4  California                0.53                         531
#
#    math_score_2017  sat_total_2017  participation_2018  \
# 0              572            1165                0.06
# 1              533            1080                0.43
# 2              553            1116                0.29
# 3              594            1208                0.05
# 4              524            1055                0.60
#
#    reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 0                         595              571            1166
# ...

# %%
# ax1 = sat_stats.plot.scatter(x = 'participation_2017',
#                      y='sat_total_2017',
#                      c='b')
# ax1.xlim(0.4, 0.8)  #can do it this way but plt is the way

# %%
#made it simplet putting them all in a subplot!

# plt.figure(figsize=(15,5))

# plt.scatter(sat_stats['participation_2017'], sat_stats['sat_total_2017'],alpha=0.5,c='b')
# plt.xlabel('Participation Rate for 2017', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')
# plt.title('Average SAT Score by State, 2017', size=18)
# #plt.xlim(0.4, 0.8)  #if i want to zoom into a range of data

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2017 that as participation rate increases for the SATs, the average score will go down.*

# %%
# plt.figure(figsize=(15,5))

# plt.scatter(sat_stats['participation_2018'], sat_stats['sat_total_2018'],alpha=0.5,c='b')
# plt.xlabel('Participation Rate for 2018', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')
# plt.title('Average SAT Score by State, 2018', size=18)
# #plt.xlim(0.4, 0.8)  #if i want to zoom into a range of data

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2018 that as participation rate increases for the SATs, the average score will go down.*

# %%
# plt.figure(figsize=(15,5))

# plt.scatter(sat_stats['participation_2019'], sat_stats['sat_total_2019'],alpha=0.5,c='b')
# plt.xlabel('Participation Rate for 2019', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')
# plt.title('Average SAT Score by State, 2019', size=18)
# #plt.xlim(0.4, 0.8)  #if i want to zoom into a range of data

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2019 that as participation rate increases for the SATs, the average score will go down.*

# %%
plt.figure(figsize=(30,15))


ax1 = plt.subplot(3,1,1)
ax1.set_title('Average SAT Score by State, 2017', size=18)
ax1.scatter(sat_stats['participation_2017'], sat_stats['sat_total_2017'],alpha=0.5,c='b')
ax1.axhline(y = np.mean(sat_stats['sat_total_2017']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
                                        #is the other way around if you want to cross the y-axios
plt.xlabel('Participation Rate for 2017', size=8, c='m')
plt.ylabel('States Average SAT Score', size=16, c='m')  
    
    
ax2 = plt.subplot(3,1,2, sharex=ax1)
ax2.set_title('Average SAT Score by State, 2018', size=18)
ax2.scatter(sat_stats['participation_2018'], sat_stats['sat_total_2018'],alpha=0.5,c='b')
ax2.axhline(y = np.mean(sat_stats['sat_total_2018']), color='orange' )  
plt.xlabel('Participation Rate for 2018', size=8, c='m')
plt.ylabel('States Average SAT Score', size=16, c='m')  

ax3 = plt.subplot(3,1,3, sharex=ax1)
ax3.set_title('Average SAT Score by State, 2019', size=18)
ax3.scatter(sat_stats['participation_2019'], sat_stats['sat_total_2019'],alpha=0.5,c='b')
ax3.axhline(y = np.mean(sat_stats['sat_total_2019']), color='orange' ) 
plt.xlabel('Participation Rate', size=14, c='m')
plt.ylabel('States Average SAT Score', size=16, c='m')
# Out:
# Text(0, 0.5, 'States Average SAT Score')

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2017 - 2019. Each dot represents a state. As participation rate increases for the SATs, the average score will go down.*

# %%
west_sat.head()
# Out:
#          state  participation_2017  reading_writing_score_2017  \
# 4   California                0.53                         531
# 37      Oregon                0.43                         560
# 47  Washington                0.64                         541
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 4               524            1055                0.60
# 37              548            1108                0.48
# 47              534            1075                0.69
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 4                          540              536            1076
# 37                         564              553            1117
# 47                         543              538            1081
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 4                 0.63                         534              531
# 37                0.51                         562              550
# ...

# %%
east_sat.head()
# Out:
#              state  participation_2017  reading_writing_score_2017  \
# 32        New York                0.67                         528
# 33  North Carolina                0.49                         546
# 46        Virginia                0.65                         561
#
#     math_score_2017  sat_total_2017  participation_2018  \
# 32              523            1052                0.79
# 33              535            1081                0.52
# 46              541            1102                0.68
#
#     reading_writing_score_2018  math_score_2018  sat_total_2018  \
# 32                         534              534            1068
# 33                         554              543            1098
# 46                         567              550            1117
#
#     participation_2019  reading_writing_score_2019  math_score_2019  \
# 32                0.79                         531              533
# 33                0.51                         554              546
# ...

# %%
# plt.figure(figsize=(7,10))


# ax1 = plt.subplot(2,1,1)
# ax1.set_title('WEST COAST, 2017', size=18)
# ax1.scatter(west_sat['participation_2017'], west_sat['sat_total_2017'],alpha=0.5,c='b')
# ax1.axhline(y = np.mean(west_sat['sat_total_2017']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
#                                         #is the other way around if you want to cross the y-axios
# plt.xlabel('Participation Rate for 2017', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')    
    
    
    
# ax2 = plt.subplot(2,1,2, sharex=ax1)
# ax2.set_title('EAST COAST, 2017', size=18)
# ax2.scatter(east_sat['participation_2017'], east_sat['sat_total_2017'],alpha=0.5,c='b')
# ax2.axhline(y = np.mean(east_sat['sat_total_2017']), color='orange' )  

# west_sat.iterrows()

# %%
# plt.figure(figsize=(5,10))


# ax1 = plt.subplot(2,1,1)
# ax1.set_title('WEST COAST, 2018', size=18)
# ax1.scatter(west_sat['participation_2018'], west_sat['sat_total_2018'],alpha=0.5,c='b')
# ax1.axhline(y = np.mean(west_sat['sat_total_2018']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
#                                         #is the other way around if you want to cross the y-axios
    
# ax2 = plt.subplot(2,1,2, sharex=ax1)
# ax2.set_title('EAST COAST, 2018', size=18)
# ax2.scatter(east_sat['participation_2018'], east_sat['sat_total_2018'],alpha=0.5,c='b')
# ax2.axhline(y = np.mean(east_sat['sat_total_2018']), color='orange' )  

# west_sat.iterrows()

# %%
#### A METHOD TO USE FOR SUBPLOTTING
# x = [0, 1, 2]

# # subplot(121)  # 1 row, 2 columns, Plot 1
# # ...
# # subplot(122)  # 1 row, 2 columns, Plot 2

# plt.figure()

# # sp1
# plt.subplot(121)
# plt.bar(x, x)

# # sp2
# plt.subplot(122)
# plt.plot(x, x)

# plt.subplot(221)
# plt.bar(x, x)

# # sp2
# plt.subplot(222)
# plt.plot(x, x)

# plt.show()

# %%
#type(west_sat['sat_total_2017'])

# %%
#type(west_sat['sat_total_2017'].tolist())

# %%
#west_sat['sat_total_2017'].tolist()[1]

# %%
# for x in west_sat['state']:
#     print(x)

# %%
#===============================AVERAGE SAT SCORE=============================

fig, axes = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True, figsize=(15, 10))  ## creates a 2 by 3 empty subplot
# https://pandas.pydata.org/pandas-docs/version/0.9.1/visualization.html   ...... section Targeting different subplots
#plt.tick_params(labelcolor="none", bottom=False, left=False)
   
   
ax1 = plt.subplot(axes[0,0])
ax2 = plt.subplot(axes[0,1])
ax3 = plt.subplot(axes[0,2])
ax4 = plt.subplot(axes[1,0])
ax5 = plt.subplot(axes[1,1])
ax6 = plt.subplot(axes[1,2])




#-----------------------------West coast---------------------
ax1.set_title('WEST COAST, 2017', size=18)
ax1.scatter(west_sat['participation_2017'], west_sat['sat_total_2017'],alpha=0.5,c='b')
ax1.axhline(y = np.mean(west_sat['sat_total_2017']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
                                        #is the other way around if you want to cross the y-axios
#labeling my scatter plot!!  woooooooooooooo
#https://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point
#---
for i, txt in enumerate(west_sat['state']):
    ax1.annotate(txt, (west_sat['participation_2017'].tolist()[i], west_sat['sat_total_2017'].tolist()[i] ))
    

ax2.set_title('WEST COAST, 2018', size=18)
ax2.scatter(west_sat['participation_2018'], west_sat['sat_total_2018'],alpha=0.5,c='b')
ax2.axhline(y = np.mean(west_sat['sat_total_2018']), color='orange' )    

for i, txt in enumerate(west_sat['state']):
    ax2.annotate(txt, (west_sat['participation_2018'].tolist()[i], west_sat['sat_total_2018'].tolist()[i] ))


ax3.set_title('WEST COAST, 2019', size=18)
ax3.scatter(west_sat['participation_2019'], west_sat['sat_total_2019'],alpha=0.5,c='b')
ax3.axhline(y = np.mean(west_sat['sat_total_2019']), color='orange' )

for i, txt in enumerate(west_sat['state']):
    ax3.annotate(txt, (west_sat['participation_2019'].tolist()[i], west_sat['sat_total_2019'].tolist()[i] ))
#------------------------------------------------------------------------
#-------------------------East Coast------------------------------
ax4.set_title('EAST COAST, 2017', size=18)
ax4.scatter(east_sat['participation_2017'], east_sat['sat_total_2017'],alpha=0.5,c='b')
ax4.axhline(y = np.mean(east_sat['sat_total_2017']), color='orange' )   

for i, txt in enumerate(east_sat['state']):
    ax4.annotate(txt, (east_sat['participation_2017'].tolist()[i], east_sat['sat_total_2017'].tolist()[i] ))


ax5.set_title('EAST COAST, 2018', size=18)
ax5.scatter(east_sat['participation_2018'], east_sat['sat_total_2018'],alpha=0.5,c='b')
ax5.axhline(y = np.mean(east_sat['sat_total_2018']), color='orange' )   

for i, txt in enumerate(east_sat['state']):
    ax5.annotate(txt, (east_sat['participation_2018'].tolist()[i], east_sat['sat_total_2018'].tolist()[i] ))


ax6.set_title('EAST COAST, 2019', size=18)
ax6.scatter(east_sat['participation_2019'], east_sat['sat_total_2019'],alpha=0.5,c='b')
ax6.axhline(y = np.mean(east_sat['sat_total_2019']), color='orange' );

for i, txt in enumerate(east_sat['state']):
    ax6.annotate(txt, (east_sat['participation_2019'].tolist()[i], east_sat['sat_total_2019'].tolist()[i] ))
    
    
#------------------------------------------------------------------------    

# fig.xlabel('Participation Rate for 2017', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')    #to label all the y and x axis:
fig.text(0.5, 0.04, 'Average Participation Rate', ha='center')  #x-axis (well not exactly,.... the 0.5value has it around the center.. if i set it to 1 it gets pushed to the right)
                                                                                ## setting 0.04 has it set to the top
          ###https://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots
fig.text(0.04, 0.5, 'Average SAT TOTAL Score', va='center', rotation='vertical')
# Out:
# Text(0.04, 0.5, 'Average SAT TOTAL Score')

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2017 - 2019  for west coast states (CA, OR, WA) and east coast states (NY, VA, NC). Each dot represents a state. East coast states beat west coast states in average SAT total score.*

# %%
east_list
# Out:
# ['New York', 'Virginia', 'North Carolina']

# %%
#===============================AVERAGE SAT MATH SCORE=============================
fig, axes = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True, figsize=(15, 10))  ## creates a 2 by 3 empty subplot
# https://pandas.pydata.org/pandas-docs/version/0.9.1/visualization.html   ...... section Targeting different subplots
#plt.tick_params(labelcolor="none", bottom=False, left=False)
     
ax1 = plt.subplot(axes[0,0])
ax2 = plt.subplot(axes[0,1])
ax3 = plt.subplot(axes[0,2])
ax4 = plt.subplot(axes[1,0])
ax5 = plt.subplot(axes[1,1])
ax6 = plt.subplot(axes[1,2])


#-----------------------------West coast---------------------
ax1.set_title('WEST COAST, 2017', size=18)
ax1.scatter(west_sat['participation_2017'], west_sat['math_score_2017'],alpha=0.5,c='b')
ax1.axhline(y = np.mean(west_sat['math_score_2017']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
                                        #is the other way around if you want to cross the y-axios
for i, txt in enumerate(west_sat['state']):
    ax1.annotate(txt, (west_sat['participation_2017'].tolist()[i], west_sat['math_score_2017'].tolist()[i] ))
    

ax2.set_title('WEST COAST, 2018', size=18)
ax2.scatter(west_sat['participation_2018'], west_sat['math_score_2018'],alpha=0.5,c='b')
ax2.axhline(y = np.mean(west_sat['math_score_2018']), color='orange' )   

for i, txt in enumerate(west_sat['state']):
    ax2.annotate(txt, (west_sat['participation_2018'].tolist()[i], west_sat['math_score_2018'].tolist()[i] ))


ax3.set_title('WEST COAST, 2019', size=18)
ax3.scatter(west_sat['participation_2019'], west_sat['math_score_2019'],alpha=0.5,c='b')
ax3.axhline(y = np.mean(west_sat['math_score_2019']), color='orange' )

for i, txt in enumerate(west_sat['state']):
    ax3.annotate(txt, (west_sat['participation_2019'].tolist()[i], west_sat['math_score_2019'].tolist()[i] ))

#------------------------------------------------------------------------
#-------------------------East Coast------------------------------
ax4.set_title('EAST COAST, 2017', size=18)
ax4.scatter(east_sat['participation_2017'], east_sat['math_score_2017'],alpha=0.5,c='b')
ax4.axhline(y = np.mean(east_sat['math_score_2017']), color='orange' )   

for i, txt in enumerate(east_sat['state']):
    ax4.annotate(txt, (east_sat['participation_2017'].tolist()[i], east_sat['math_score_2017'].tolist()[i] ))

    
ax5.set_title('EAST COAST, 2018', size=18)
ax5.scatter(east_sat['participation_2018'], east_sat['math_score_2018'],alpha=0.5,c='b')
ax5.axhline(y = np.mean(east_sat['math_score_2018']), color='orange' )    

for i, txt in enumerate(east_sat['state']):
    ax5.annotate(txt, (east_sat['participation_2018'].tolist()[i], east_sat['math_score_2018'].tolist()[i] ))


ax6.set_title('EAST COAST, 2019', size=18)
ax6.scatter(east_sat['participation_2019'], east_sat['math_score_2019'],alpha=0.5,c='b')
ax6.axhline(y = np.mean(east_sat['math_score_2019']), color='orange' );

for i, txt in enumerate(east_sat['state']):
    ax6.annotate(txt, (east_sat['participation_2019'].tolist()[i], east_sat['math_score_2019'].tolist()[i] ))

#------------------------------------------------------------------------    

# fig.xlabel('Participation Rate for 2017', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')    #to label all the y and x axis:
fig.text(0.5, 0.04, 'Average Participation Rate', ha='center')  #x-axis (well not exactly,.... the 0.5value has it around the center.. if i set it to 1 it gets pushed to the right)
                                                                                ## setting 0.04 has it set to the top
          ###https://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots
fig.text(0.04, 0.5, 'Average SAT Math Score', va='center', rotation='vertical')
# Out:
# Text(0.04, 0.5, 'Average SAT Math Score')

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2017 - 2019  for west coast states (CA, OR, WA) and east coast states (NY, VA, NC). Each dot represents a state. East coast states beat west coast states in average SAT Math score.*

# %%
#===============================AVERAGE SAT ENGLISH_WRITING SCORE=============================
fig, axes = plt.subplots(nrows=2, ncols=3, sharex=True, sharey=True, figsize=(15, 10))  ## creates a 2 by 3 empty subplot
# https://pandas.pydata.org/pandas-docs/version/0.9.1/visualization.html   ...... section Targeting different subplots
#plt.tick_params(labelcolor="none", bottom=False, left=False)
     
ax1 = plt.subplot(axes[0,0])
ax2 = plt.subplot(axes[0,1])
ax3 = plt.subplot(axes[0,2])
ax4 = plt.subplot(axes[1,0])
ax5 = plt.subplot(axes[1,1])
ax6 = plt.subplot(axes[1,2])


#-----------------------------West coast---------------------
ax1.set_title('WEST COAST, 2017', size=18)
ax1.scatter(west_sat['participation_2017'], west_sat['reading_writing_score_2017'],alpha=0.5,c='b')
ax1.axhline(y = np.mean(west_sat['reading_writing_score_2017']), color='orange' )   #ty Kevin for helping my brainfart seeing it literally
                                        #is the other way around if you want to cross the y-axios
for i, txt in enumerate(west_sat['state']):
    ax1.annotate(txt, (west_sat['participation_2017'].tolist()[i], west_sat['reading_writing_score_2017'].tolist()[i] ))
    

ax2.set_title('WEST COAST, 2018', size=18)
ax2.scatter(west_sat['participation_2018'], west_sat['reading_writing_score_2018'],alpha=0.5,c='b')
ax2.axhline(y = np.mean(west_sat['reading_writing_score_2018']), color='orange' )    

for i, txt in enumerate(west_sat['state']):
    ax2.annotate(txt, (west_sat['participation_2018'].tolist()[i], west_sat['reading_writing_score_2018'].tolist()[i] ))
    

ax3.set_title('WEST COAST, 2019', size=18)
ax3.scatter(west_sat['participation_2019'], west_sat['reading_writing_score_2019'],alpha=0.5,c='b')
ax3.axhline(y = np.mean(west_sat['reading_writing_score_2019']), color='orange' )

for i, txt in enumerate(west_sat['state']):
    ax3.annotate(txt, (west_sat['participation_2019'].tolist()[i], west_sat['reading_writing_score_2019'].tolist()[i] ))

#------------------------------------------------------------------------
#-------------------------East Coast------------------------------
ax4.set_title('EAST COAST, 2017', size=18)
ax4.scatter(east_sat['participation_2017'], east_sat['reading_writing_score_2017'],alpha=0.5,c='b')
ax4.axhline(y = np.mean(east_sat['reading_writing_score_2017']), color='orange' )   

for i, txt in enumerate(east_sat['state']):
    ax4.annotate(txt, (east_sat['participation_2017'].tolist()[i], east_sat['reading_writing_score_2017'].tolist()[i] ))


ax5.set_title('EAST COAST, 2018', size=18)
ax5.scatter(east_sat['participation_2018'], east_sat['reading_writing_score_2018'],alpha=0.5,c='b')
ax5.axhline(y = np.mean(east_sat['reading_writing_score_2018']), color='orange' )   

for i, txt in enumerate(east_sat['state']):
    ax5.annotate(txt, (east_sat['participation_2018'].tolist()[i], east_sat['reading_writing_score_2018'].tolist()[i] ))


ax6.set_title('EAST COAST, 2019', size=18)
ax6.scatter(east_sat['participation_2019'], east_sat['reading_writing_score_2019'],alpha=0.5,c='b')
ax6.axhline(y = np.mean(east_sat['reading_writing_score_2019']), color='orange' );

for i, txt in enumerate(east_sat['state']):
    ax6.annotate(txt, (east_sat['participation_2019'].tolist()[i], east_sat['reading_writing_score_2019'].tolist()[i] ))

#------------------------------------------------------------------------    

# fig.xlabel('Participation Rate for 2017', size=14, c='m')
# plt.ylabel('States Average SAT Score', size=14, c='m')    #to label all the y and x axis:
fig.text(0.5, 0.04, 'Average Participation Rate', ha='center')  #x-axis (well not exactly,.... the 0.5value has it around the center.. if i set it to 1 it gets pushed to the right)
                                                                                ## setting 0.04 has it set to the top
          ###https://stackoverflow.com/questions/16150819/common-xlabel-ylabel-for-matplotlib-subplots
fig.text(0.04, 0.5, 'Average SAT Reading&Writing Score', va='center', rotation='vertical')
# Out:
# Text(0.04, 0.5, 'Average SAT Reading&Writing Score')

# %% [markdown]
# *Interpretation: The above image shows SAT data from 2017 - 2019  for west coast states (CA, OR, WA) and east coast states (NY, VA, NC). Each dot represents a state. East coast states beat west coast states in average SAT Reading&Writing score.*

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
#
# As state participation increases for taking the SAT, the average score goes down. The highest average scoring states (Mississippi, North Dakota, Iowan, Wyoming, and Wisconsin) were the least participating states for the States.  Inversely, the lowest scoring states (Connecticut, Delaware, Michigan, District of Columbia, and New Hampshire) had the highest participation rates for the SATs.
#
# # ![](https://m.media-amazon.com/images/I/71HbeKyARtL._SS500_.jpg)
#
# Now looking at the big west coast states versus a few east coast states. These states that were chosen are in the middle of the pack for participation in the SATs.  East coast states were chosen based on participation rates that almost matches the rates of the west coast states of CA, OR, and WA. East coast states that were chosen are NY, VA, and NC. Averaging out the east and west coasts total SAT score, they have a 1 point difference in the Sat_total_2017 score.  The competing states do not have a stark difference in scores, but east coast pulls ahead slightly against the west coast states in Math, Reading/Writing and Total SAT score.
#
# States that are fully participating in taking the SATs could invest more into quality education to prepare students for taking them and get higher scores out of them. Looking at the battle between east coast versus west coast states, boths sides have room for improvement.  Looking at California, they are the richest state in the country.  They should invest more into education that prepares the student for SAT and college to increase the college graduation rate and also create an educated indivdual to prepare them for the job market.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources! ---
